# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df = pd.read_excel("./data/housing_data.xlsx",)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

def reg_plot(ax, X, y, y_pred, title, color="steelblue"):
    ax.scatter(X, y, c=color, edgecolor="white", s=70)
    ax.plot(X, y_pred, color="black", lw=2)
    ax.set_title(title)
    return


def res_plot(ax, y_pred, y, title, color="steelblue"):
    ax.scatter(y_pred, y_pred - y, c=color, marker="o", edgecolor="white", s=70)
    ax.hlines(y=0, xmin=0, xmax=1, color="black", lw=2)
    ax.axes.set_aspect("equal")
    ax.set_title(title)


def store_results(df, model_name, y_train, y_test, y_train_pred, y_test_pred):

    MSE_train = mean_squared_error(y_train, y_train_pred)
    MSE_test = mean_squared_error(y_test, y_test_pred)

    R2_train = r2_score(y_train, y_train_pred)
    R2_test = r2_score(y_test, y_test_pred)

    data = {
        "Model": model_name,
        "MSE Train": [MSE_train],
        "MSE Test": [MSE_test],
        "R2 Train": [R2_train],
        "R2 Test": [R2_test],
    }
    dft = pd.DataFrame(data=data)
    return df.append(dft, ignore_index=True)

# %%
# Extract data
X = df[["LSTAT"]].values
y = df["MEDV"].values

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# Very important to scale both X and y data.

# %%
# Standardization
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# Scale y data
nm = MinMaxScaler()
y_train = y_train.reshape(-1, 1) # Required for sklearn api
y_test = y_test.reshape(-1, 1)
nm.fit(y_train)
y_train_scaled = nm.transform(y_train)
y_test_scaled = nm.transform(y_test)

# Plot data to validate
fig, ax = plt.subplots(1, 1)
ax.scatter(X_train_std, y_train_scaled)
ax.scatter(X_test_std, y_test_scaled)
ax.set_title('Scaled Data')
ax.set_xlabel('LSTAT (Standardized)')
ax.set_ylabel('MEDV (Scaled)')
# Out:
# Text(0, 0.5, 'MEDV (Scaled)')

# %%
tf.keras.backend.clear_session()

model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(1,)),
    tf.keras.layers.Dense(units=16, activation='relu', name='hidden1'),
    tf.keras.layers.Dense(units=1, name='output')
    ])

model.summary()

model.compile(
    optimizer='adam',
    loss='mean_squared_error',
    metrics=['mean_absolute_percentage_error'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# hidden1 (Dense)              (None, 16)                32
# _________________________________________________________________
# output (Dense)               (None, 1)                 17
# =================================================================
# Total params: 49
# Trainable params: 49
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf_fit = model.fit(x=X_train_std, y=y_train_scaled,
        batch_size=16,
        validation_split=0.1,
        epochs=100, 
        verbose=1)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.1630 - mean_absolute_percentage_error: 1640256.8750 - val_loss: 0.0927 - val_mean_absolute_percentage_error: 79.2615
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0819 - mean_absolute_percentage_error: 356199.6875 - val_loss: 0.0430 - val_mean_absolute_percentage_error: 48.1335
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0404 - mean_absolute_percentage_error: 1230026.7500 - val_loss: 0.0211 - val_mean_absolute_percentage_error: 41.4513
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0233 - mean_absolute_percentage_error: 1465517.0000 - val_loss: 0.0155 - val_mean_absolute_percentage_error: 39.7738
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0174 - mean_absolute_percentage_error: 1547220.2500 - val_loss: 0.0159 - val_mean_absolute_percentage_error: 40.5047
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0157 - mean_absolute_percentage_error: 1441144.0000 - val_loss: 0.0163 - val_mean_absolute_percentage_error: 39.7639
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.
- val_loss: 0.0141 - val_mean_absolute_percentage_error: 34.6407
# Epoch 83/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0137 - mean_absolute_percentage_error: 1119869.6250 - val_loss: 0.0136 - val_mean_absolute_percentage_error: 33.8416
# Epoch 84/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0137 - mean_absolute_percentage_error: 1068542.2500 - val_loss: 0.0140 - val_mean_absolute_percentage_error: 33.9558
# Epoch 85/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0137 - mean_absolute_percentage_error: 1129198.5000 - val_loss: 0.0135 - val_mean_absolute_percentage_error: 34.2914
# Epoch 86/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0137 - mean_absolute_percentage_error: 1182011.8750 - val_loss: 0.0133 - val_mean_absolute_percentage_error: 32.8800
# Epoch 87/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0137 - mean_absolute_percentage_error: 1031390.6875 - val_loss: 0.0133 - val_mean_absolute_percentage_error: 34.2051
# Epoch 88/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0138 - mean_absolute_percentage_error: 1088424.7500 - val_loss: 0.0137 - val_mean_absolute_percentage_error: 33.8141
# Epoch 89/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0136 - mean_absolute_percentage_error: 1136243.8750 - val_loss: 0.0135 - val_mean_absolute_percentage_error: 34.3583
# Epoch 90/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0137 - mean_absolute_percentage_error: 1117248.2500 - val_loss: 0.0135 - val_mean_absolute_percentage_error: 33.6543
# Epoch 91/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0138 - mean_absolute_percentage_error: 1074753.2500 - val_loss: 0.0136 - val_mean_absolute_percentage_error: 35.1521
# Epoch 92/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0137 - mean_absolute_percentage_error: 1074431.2500 - val_loss: 0.0135 - val_mean_absolute_percentage_error: 33.1716
# Epoch 93/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0138 - mean_absolute_percentage_error: 1050752.6250 - val_loss: 0.0143 - val_mean_absolute_percentage_error: 34.1289
# Epoch 94/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0137 - mean_absolute_percentage_error: 1106672.2500 - val_loss: 0.0131 - val_mean_absolute_percentage_error: 34.8755
# Epoch 95/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0137 - mean_absolute_percentage_error: 1236526.8750 - val_loss: 0.0135 - val_mean_absolute_percentage_error: 33.9330
# Epoch 96/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0137 - mean_absolute_percentage_error: 959469.3125 - val_loss: 0.0135 - val_mean_absolute_percentage_error: 33.0608
# Epoch 97/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0138 - mean_absolute_percentage_error: 1212036.3750 - val_loss: 0.0132 - val_mean_absolute_percentage_error: 34.5829
# Epoch 98/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0139 - mean_absolute_percentage_error: 1117698.3750 - val_loss: 0.0141 - val_mean_absolute_percentage_error: 34.2639
# Epoch 99/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0137 - mean_absolute_percentage_error: 1055383.3750 - val_loss: 0.0138 - val_mean_absolute_percentage_error: 33.6614
# Epoch 100/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.0137 - mean_absolute_percentage_error: 1098099.3750 - val_loss: 0.0133 - val_mean_absolute_percentage_error: 34.7540

# %%
hist = tf_fit.history

fig = plt.figure(figsize=(12, 5))
ax = fig.add_subplot(1, 2, 1)
ax.plot(hist['loss'], lw=3)
ax.plot(hist['val_loss'], lw=3)
ax.set_title('Training loss', size=15)
ax.set_xlabel('Epoch', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)
ax.legend(['train','val'])

ax = fig.add_subplot(1, 2, 2)
ax.plot(hist['mean_absolute_percentage_error'], lw=3)
ax.plot(hist['val_mean_absolute_percentage_error'], lw=3)
ax.set_title('Training MAPE', size=15)
ax.set_xlabel('Epoch', size=15)
ax.tick_params(axis='both', which='major', labelsize=15)
plt.tight_layout()
ax.legend(['train','val'])

# %%
y_train_pred = model.predict(X_train_std)
y_test_pred = model.predict(X_test_std)

# %%
# Indices for sorting during plotting
idx_train = np.argsort(X_train_std, axis=0).ravel()
idx_test = np.argsort(X_test_std, axis=0).ravel()

fig, ax = plt.subplots(
    1, 2, figsize=(10, 5), constrained_layout=True, sharex=True, sharey=True
)
reg_plot(
    ax=ax[0],
    X=X_train_std[idx_train, :1],
    y=y_train_scaled[idx_train],
    y_pred=y_train_pred[idx_train],
    title="Train",
)
reg_plot(
    ax=ax[1],
    X=X_test_std[idx_test, :1],
    y=y_test_scaled[idx_test],
    y_pred=y_test_pred[idx_test],
    title="test",
    color="limegreen",
)
fig.supxlabel("Lower status of the population [LSTAT]")
fig.supylabel("Median value of homes in $1000s [MEDV]")

fig, ax = plt.subplots(
    1, 2, figsize=(9, 5), constrained_layout=True, sharex=True, sharey=True
)
res_plot(ax=ax[0], y_pred=y_train_pred, y=y_train_scaled, title="Train")
res_plot(ax=ax[1], y_pred=y_test_pred, y=y_test_scaled, title="Test", color="limegreen")
fig.supxlabel("Predicted values")
fig.supylabel("Residual")

df = store_results(
    df=pd.DataFrame(),
    model_name='ANN',
    y_train=y_train_scaled,
    y_train_pred=y_train_pred,
    y_test=y_test_scaled,
    y_test_pred=y_test_pred,
)
# Out:
# C:\Users\nnnpo\AppData\Local\Temp\ipykernel_67152\4189812546.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   return df.append(dft, ignore_index=True)

# %%
display(df)
# Out:
#   Model  MSE Train  MSE Test  R2 Train   R2 Test
# 0   ANN   0.013575  0.015509  0.675695  0.622825
