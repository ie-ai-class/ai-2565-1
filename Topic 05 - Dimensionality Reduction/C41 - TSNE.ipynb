# %% [markdown]
# # TSNE
# Nonlinear mappings

# %%
import matplotlib.pyplot as plt

def plot_data(X,y, plotType="normal"):
    fig, ax = plt.subplots()
    ax.scatter(X[y == 0, 0], X[y == 0, 1], color='red', marker='^', alpha=0.5)
    ax.scatter(X[y == 1, 0], X[y == 1, 1], color='blue', marker='o', alpha=0.5)
    if plotType == "normal":
        ax.set_title('Original Data')
        ax.set_xlabel('Axis 1')
        ax.set_ylabel('Axis 2')
    elif plotType == "KPCA":
        ax.set_title('KPCA')
        ax.set_xlabel('PC1')
        ax.set_ylabel('PC2')
    elif plotType == "TSNE":
        ax.set_title('TSNE')
        ax.set_xlabel('TSNE1')
        ax.set_ylabel('TSNE2')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Moon data

# %%
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=100, random_state=123)
plot_data(X,y)

# %% [markdown]
# ### KPCA

# %%
from sklearn.decomposition import KernelPCA
scikit_kpca = KernelPCA(n_components=2, kernel='rbf', gamma=15)
X_kpca = scikit_kpca.fit_transform(X)
plot_data(X_kpca,y,"KPCA")

# %% [markdown]
# ## TSNE

# %%
from sklearn.manifold import TSNE
scikit_tsne = TSNE(n_components=2, perplexity=10, learning_rate=100)
X_tsne = scikit_tsne.fit_transform(X)
plot_data(X_tsne,y,"TSNE")

# %% [markdown]
# ## Concentric circle

# %%
from sklearn.datasets import make_circles
X, y = make_circles(n_samples=1000, random_state=123, noise=0.1, factor=0.2)
plot_data(X,y)

# %% [markdown]
# ### KPCA

# %%
scikit_kpca = KernelPCA(n_components=2, kernel='rbf', gamma=15)
X_kpca = scikit_kpca.fit_transform(X)
plot_data(X_kpca,y,"KPCA")

# %%
from sklearn.manifold import TSNE
scikit_tsne = TSNE(n_components=2, perplexity=10, learning_rate=300)
X_tsne = scikit_tsne.fit_transform(X)
plot_data(X_tsne,y,"TSNE")
