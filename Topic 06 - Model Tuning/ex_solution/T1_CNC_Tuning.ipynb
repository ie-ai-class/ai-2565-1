# %% [markdown]
# # CNC Mill Tool Wear
# - https://www.kaggle.com/shasun/tool-wear-detection-in-cnc-mill
# - Predict "Machining_Process"

# %% [markdown]
# ## Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
import os
path_parent = os.path.dirname(os.getcwd())
saveFolder = os.path.join(path_parent, 'Topic 02 - Classification', 'Data_CNC_Processed')
print(saveFolder)
#saveFolder = '..\Topic 02 - Classification\Data_CNC_Processed'
filename = 'pred_machining_process'
compression = 'gzip'
df = pd.read_pickle(f'{saveFolder}/{filename}.pkl',compression=compression)
df.head(3)
# Out:
# f:\Work\Coding\Class\ai-class-2564-1\Topic 02 - Classification\Data_CNC_Processed
#    X1_ActualPosition  X1_ActualVelocity  X1_ActualAcceleration  \
# 0              198.0                0.0                   0.00
# 1              198.0              -10.8                -350.00
# 2              196.0              -17.8                  -6.25
#
#    X1_CommandPosition  X1_CommandVelocity  X1_CommandAcceleration  \
# 0               198.0                 0.0                0.000000
# 1               198.0               -13.6             -358.000000
# 2               196.0               -17.9               -0.000095
#
#    X1_CurrentFeedback  X1_DCBusVoltage  X1_OutputCurrent  X1_OutputVoltage  \
# 0                0.18           0.0207             329.0              2.77
# 1              -10.90           0.1860             328.0             23.30
# 2               -8.59           0.1400             328.0             30.60
#
#    ...  S1_OutputCurrent  S1_OutputVoltage  S1_OutputPower  S1_SystemInertia  \
# 0  ...             329.0               0.0    6.960000e-07              12.0
# 1  ...             328.0               0.0   -5.270000e-07              12.0
# 2  ...             328.0               0.0    9.100000e-07              12.0
#
#    M1_CURRENT_PROGRAM_NUMBER  M1_sequence_number  M1_CURRENT_FEEDRATE  \
# 0                        1.0                 0.0                 50.0
# 1                        1.0                 4.0                 50.0
# 2                        1.0                 7.0                 50.0
#
#    Machining_Process  feedrate  clamp_pressure
# 0                  7         6             4.0
# 1                  7         6             4.0
# 2                  7         6             4.0
#
# [3 rows x 50 columns]

# %%
colsX = np.array([item for item in df.columns if item not in 'Machining_Process'])
X = df[colsX].values
y = df['Machining_Process'].values

# %%
# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0, stratify=y)

# %% [markdown]
# ## Contruct pipeline

# %%
from sklearn.feature_selection import VarianceThreshold
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier as RF
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(solver='liblinear', penalty='l1', C=0.1, multi_class='ovr')

var = VarianceThreshold(threshold=0)
l1 = SelectFromModel(estimator=lr, norm_order=1, max_features=20)
clf = RF(n_estimators=50)

# Construct pipeline object
pipe = Pipeline([
    ('var', var)
    ('scl', StandardScaler()),
    ('l1',l1),
    ('clf', clf)])

# %% [markdown]
# ## Comparing training and validation accuracy

# %%
# WIthout cross validation
pipe.fit(X_train, y_train)
train_acc = pipe.score(X_train,y_train)
test_acc = pipe.score(X_test,y_test)

print(f"Training acc: {train_acc:4.3f}")
print(f"Test acc:     {test_acc:4.3f}")
# Out:
# Training acc: 1.000
# Test acc:     0.694

# %%
# With cross validation
from sklearn.model_selection import cross_val_score
scores = cross_val_score(estimator=pipe,
                         X=X_train,
                         y=y_train,
                         cv=5,
                         n_jobs=1)

arrayPrint =   ', '.join([f'{el:3.2f}' for el in scores])
print(f"Score:", arrayPrint)
print("\nCrossed-validation accuracy")  
print(f"Mean:{np.mean(scores):6.3f}")
print(f"Std:{np.std(scores):6.3f}")
# Out:
# Score: 0.64, 0.62, 0.64, 0.71, 0.67
#
# Crossed-validation accuracy
# Mean: 0.656
# Std: 0.030

# %%
# Get parameter names
for k, v in pipe.get_params().items():
    print(f"{k:25.25s}: {str(v)}")
# Out:
# memory                   : None
# steps                    : [('scl', StandardScaler()), ('l1', SelectFromModel(estimator=LogisticRegression(C=0.1, multi_class='ovr',
#                                              penalty='l1', solver='liblinear'),
#                 max_features=20)), ('clf', RandomForestClassifier(n_estimators=50))]
# verbose                  : False
# scl                      : StandardScaler()
# l1                       : SelectFromModel(estimator=LogisticRegression(C=0.1, multi_class='ovr',
#                                              penalty='l1', solver='liblinear'),
#                 max_features=20)
# clf                      : RandomForestClassifier(n_estimators=50)
# scl__copy                : True
# scl__with_mean           : True
# scl__with_std            : True
# l1__estimator__C         : 0.1
# l1__estimator__class_weig: None
# l1__estimator__dual      : False
# l1__estimator__fit_interc: True
# l1__estimator__intercept_: 1
# l1__estimator__l1_ratio  : None
# l1__estimator__max_iter  : 100
# l1__estimator__multi_clas: ovr
# l1__estimator__n_jobs    : None
# l1__estimator__penalty   : l1
# l1__estimator__random_sta: None
# l1__estimator__solver    : liblinear
# l1__estimator__tol       : 0.0001
# l1__estimator__verbose   : 0
# l1__estimator__warm_start: False
# l1__estimator            : LogisticRegression(C=0.1, multi_class='ovr', penalty='l1', solver='liblinear')
# l1__importance_getter    : auto
# l1__max_features         : 20
# l1__norm_order           : 1
# l1__prefit               : False
# l1__threshold            : None
# clf__bootstrap           : True
# clf__ccp_alpha           : 0.0
# clf__class_weight        : None
# clf__criterion           : gini
# clf__max_depth           : None
# clf__max_features        : auto
# clf__max_leaf_nodes      : None
# clf__max_samples         : None
# clf__min_impurity_decreas: 0.0
# clf__min_impurity_split  : None
# clf__min_samples_leaf    : 1
# clf__min_samples_split   : 2
# clf__min_weight_fraction_: 0.0
# clf__n_estimators        : 50
# clf__n_jobs              : None
# clf__oob_score           : False
# clf__random_state        : None
# clf__verbose             : 0
# clf__warm_start          : False

# %%
set1 = {
    "l1__max_features": [20, 30, 40],
    "clf__n_estimators": [25, 50, 75],
    "clf__max_samples": [None],
    "clf__max_features": ["auto"],
    "clf__max_depth": [None],
      }
param_grid = [set1]

# %%
from sklearn.model_selection import GridSearchCV

gs = GridSearchCV(estimator=pipe, 
                  param_grid=param_grid, 
                  scoring='accuracy', 
                  cv=5,
                  n_jobs=-1)

# %%
gs.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scl', StandardScaler()),
#                                        ('l1',
#                                         SelectFromModel(estimator=LogisticRegression(C=0.1,
#                                                                                      multi_class='ovr',
#                                                                                      penalty='l1',
#                                                                                      solver='liblinear'),
#                                                         max_features=20)),
#                                        ('clf',
#                                         RandomForestClassifier(n_estimators=50))]),
#              n_jobs=-1,
#              param_grid=[{'clf__max_depth': [None],
#                           'clf__max_features': ['auto'],
#                           'clf__max_samples': [None],
#                           'clf__n_estimators': [25, 50, 75],
#                           'l1__max_features': [20, 30, 40]}],
#              scoring='accuracy')

# %%
df = pd.DataFrame(gs.cv_results_)
df = df.sort_values(by=['rank_test_score'])
display(df)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 7      47.205173      4.302207         0.130850        0.076058
# 8      37.568402      2.397548         0.079560        0.010759
# 4      64.367832     11.596524         0.294869        0.030789
# 5      69.933111     12.916035         0.291666        0.076516
# 1      55.469833     12.093970         0.169237        0.030392
# 6      55.047105      8.622972         0.320888        0.083752
# 3      66.774073     23.228603         0.288678        0.033719
# 2      61.207644     15.624290         0.179040        0.024366
# 0      60.455384     10.944786         0.169746        0.021199
#
#   param_clf__max_depth param_clf__max_features param_clf__max_samples  \
# 7                 None                    auto                   None
# 8                 None                    auto                   None
# 4                 None                    auto                   None
# 5                 None                    auto                   None
# 1                 None                    auto                   None
# 6                 None                    auto                   None
# 3                 None                    auto                   None
# 2                 None                    auto                   None
# 0                 None                    auto                   None
#
#   param_clf__n_estimators param_l1__max_features  \
# 7                      75                     30
# 8                      75                     40
# 4                      50                     30
# 5                      50                     40
# 1                      25                     30
# 6                      75                     20
# 3                      50                     20
# 2                      25                     40
# 0                      25                     20
#
#                                               params  split0_test_score  \
# 7  {'clf__max_depth': None, 'clf__max_features': ...           0.700282
# 8  {'clf__max_depth': None, 'clf__max_features': ...           0.681921
# 4  {'clf__max_depth': None, 'clf__max_features': ...           0.692938
# 5  {'clf__max_depth': None, 'clf__max_features': ...           0.666102
# 1  {'clf__max_depth': None, 'clf__max_features': ...           0.655367
# 6  {'clf__max_depth': None, 'clf__max_features': ...           0.578814
# 3  {'clf__max_depth': None, 'clf__max_features': ...           0.631638
# 2  {'clf__max_depth': None, 'clf__max_features': ...           0.641243
# 0  {'clf__max_depth': None, 'clf__max_features': ...           0.614124
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 7           0.677401           0.663277           0.691243           0.689831
# 8           0.664689           0.677119           0.666667           0.673446
# 4           0.677684           0.667232           0.671469           0.632768
# 5           0.663559           0.675706           0.669774           0.660169
# 1           0.672034           0.674859           0.661299           0.663277
# 6           0.641243           0.631073           0.692655           0.687288
# 3           0.628531           0.623446           0.651130           0.668079
# 2           0.639548           0.639548           0.642090           0.634746
# 0           0.595763           0.516384           0.645763           0.658757
#
#    mean_test_score  std_test_score  rank_test_score
# 7         0.684407        0.012835                1
# 8         0.672768        0.006413                2
# 4         0.668418        0.019843                3
# 5         0.667062        0.005344                4
# 1         0.665367        0.007148                5
# 6         0.646215        0.041571                6
# 3         0.640565        0.016650                7
# 2         0.639435        0.002543                8
# 0         0.606158        0.050132                9

# %%
print(gs.best_score_)
print(gs.best_params_)
# Out:
# 0.6844067796610169
# {'clf__max_depth': None, 'clf__max_features': 'auto', 'clf__max_samples': None, 'clf__n_estimators': 75, 'l1__max_features': 30}

# %%
gs.score(X_test,y_test)
# Out:
# 0.7417611389401529
